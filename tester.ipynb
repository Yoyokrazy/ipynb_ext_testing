# %% [markdown]
# ![nav snippet](attachment:image.png)
# ![upper left](attachment:image-2.png)
#
# ![datetime](attachment:image-3.png)
# ![errors](attachment:image-4.png)
#
# ![markdown code](attachment:image-5.png)
